# %% [markdown]
# ## Get components pr. sample

# %%
import os
os.chdir("/faststorage/project/jsp_student_projects/miRNA_DGD_DE_F2024/DGD/bulkDGD_git")

import sys
sys.path.append("/faststorage/project/jsp_student_projects/miRNA_DGD_DE_F2024/DGD/bulkDGD_git")


# Import the 'logging' module
import logging as log
# Import the 'model' module
from bulkDGD.core import model
# Import the 'ioutil' module 
from bulkDGD import ioutil


import numpy as np
import pandas as pd

import os
print (os.getcwd())



#------------------------------ Logging ------------------------------#


# Set the logging options so that every message
# above and including the INFO level is reported
log.basicConfig(level = "INFO")

logger = log.getLogger(__name__)


#---------------------- Preprocess the samples -----------------------#



df_rep  = \
    ioutil.load_representations(csv_file = "/home/elisalaegsgaard/jsp_student_projects/miRNA_DGD_DE_F2024/DGD/data/full_TCGA/representations.csv",
                                sep = ",",
                                split = False)

config_model = ioutil.load_config_model("/faststorage/project/jsp_student_projects/miRNA_DGD_DE_F2024/DGD/bulkDGD_git/bulkDGD/ioutil/configs/model/model.yaml")
dgd_model = model.DGDModel(**config_model)

df_prob_rep, df_prob_comp = \
    dgd_model.get_probability_density(df_rep = df_rep)
# Out:
# /faststorage/project/jsp_student_projects/miRNA_DGD_DE_F2024/DGD/bulkDGD_git
# INFO:bulkDGD.core.model:The parameters were successfully loaded from '/faststorage/project/jsp_student_projects/miRNA_DGD_DE_F2024/DGD/bulkDGD_git/bulkDGD/ioutil/data/gmm.pth'.
# INFO:bulkDGD.core.model:The Gaussian mixture model was successfully set.
# INFO:bulkDGD.core.model:The parameters were successfully loaded from '/faststorage/project/jsp_student_projects/miRNA_DGD_DE_F2024/DGD/bulkDGD_git/bulkDGD/ioutil/data/dec.pth'.
# INFO:bulkDGD.core.model:The decoder was successfully set.

# %%
pd.set_option('display.max_rows', 40)  # Set max rows option to None to display all rows
pd.set_option('display.max_columns', None)  # Set max columns option to None to display all columns

display(df_prob_rep)
# Out:
#                   0             1             2             3             4  \
# 0      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2      0.000000e+00  5.058687e-43  0.000000e+00  0.000000e+00  0.000000e+00
# 3      9.919003e-23  1.241057e-18  6.372174e-29  1.124142e-14  1.641039e-25
# 4      1.342226e-13  1.893547e-35  2.073639e-38  1.012956e-33  2.567697e-28
# ...             ...           ...           ...           ...           ...
# 10677  9.549052e-06  2.676297e-11  6.019019e-14  2.452780e-20  8.200725e-20
# 10678  4.439826e-39  7.446774e-32  7.006492e-45  1.245894e-36  2.071764e-40
# 10679  0.000000e+00  3.643376e-44  0.000000e+00  2.466285e-43  9.388700e-44
# 10680  1.396512e-20  8.699981e-18  4.356429e-23  3.430646e-25  1.615845e-23
# 10681  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
# ...

# %%
df_prob_rep.to_csv("/home/elisalaegsgaard/jsp_student_projects/miRNA_DGD_DE_F2024/data/plot_mat/df_prob_rep.csv",
                           sep = ",",
                           header = True,
                           index = True)

# %%
df_prob_comp
# Out:
#                                   0             1             2             3  \
# max_prob_density_comp
# 28                     9.789779e-09  9.322573e-12  4.456041e-19  7.497589e-19
# 13                     4.564418e+03  1.821892e+00  6.488407e-13  1.364220e+02
# 43                     1.688817e+10  7.308382e+03  5.591227e+03  1.120170e+09
# 24                     2.704677e-06  6.337566e-11  6.027506e-15  1.912327e-04
# 15                     9.586654e-23  9.492686e-17  4.584675e-17  2.595226e-02
# ...                             ...           ...           ...           ...
# 40                     3.222986e-44  0.000000e+00  3.466751e-22  7.785002e-25
# 41                     4.239055e-21  3.561467e-05  7.840326e-15  1.459506e-07
# 33                     0.000000e+00  1.589970e-21  6.881777e-42  1.811512e-30
# 9                      2.207910e-10  8.043692e-08  3.045045e-19  9.050165e-05
# 8                      4.512101e-31  1.645249e-13  1.757281e-20  1.098179e-03
#
# ...
